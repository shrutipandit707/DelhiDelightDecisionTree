# %% [markdown]
# ## Delhi Delight Decision Tree

# %% [markdown]
# We work at Delhi Delights! which is a food delivery company in Delhi. It offers a premium membership called ‘Delighted Members’, with which there is no delivery cost for your order. Lately, the number of purchases of this premium membership has been going down. Now, based on past data, Delhi Delights! wants to predict which of the customers will buy the 'Delighted Members' membership and which ones will not.

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the csv file and putting it into 'df' object.
df = pd.read_csv(r"C:\Users\spandit\Desktop\ITS\Personal\AIML\Tree_Models\Delhi-Delight.csv")
df.head()
# Out:
#    Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                           1.5                             11
# 1                           2.5                             11
# 2                           2.5                             11
# 3                           3.5                             11
# 4                           3.5                             11
#
#   "Delighted Members" Purchase
# 0                          Yes
# 1                           No
# 2                           No
# 3                           No
# 4                           No

# %%
df.columns
# Out:
# Index(['Average Delivery Rating (a1)', 'Average Orders per month (a2)',
#        '"Delighted Members" Purchase'],
#       dtype='object')

# %%
df.head(len(df))
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                            1.5                             11
# 1                            2.5                             11
# 2                            2.5                             11
# 3                            3.5                             11
# 4                            3.5                             11
# 5                            4.5                             11
# 6                            1.5                             13
# 7                            2.5                             13
# 8                            2.5                             13
# 9                            3.5                             13
# 10                           3.5                             13
# 11                           4.5                             13
# 12                           1.5                             15
# 13                           2.5                             15
# 14                           2.5                             15
# 15                           3.5                             15
# 16                           3.5                             15
# 17                           4.5                             15
# 18                           1.5                             27
# 19                           2.5                             27
# 20                           2.5                             27
# 21                           3.5                             27
# 22                           4.5                             27
# 23                           4.5                             27
# 24                           1.5                             39
# 25                           2.5                             39
# 26                           2.5                             39
# 27                           3.5                             39
# 28                           4.5                             39
# 29                           4.5                             39
#
#    "Delighted Members" Purchase
# 0                           Yes
# 1                            No
# 2                            No
# 3                            No
# 4                            No
# 5                           Yes
# 6                           Yes
# 7                            No
# 8                            No
# 9                            No
# 10                           No
# 11                           No
# 12                          Yes
# 13                           No
# 14                           No
# 15                           No
# 16                           No
# 17                          Yes
# 18                           No
# 19                          Yes
# 20                          Yes
# 21                          Yes
# 22                          Yes
# 23                          Yes
# 24                           No
# 25                          Yes
# 26                          Yes
# 27                          Yes
# 28                          Yes
# 29                          Yes

# %%
df.shape
# Out:
# (30, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Average Delivery Rating (a1)   30 non-null     float64
#  1   Average Orders per month (a2)  30 non-null     int64
#  2   "Delighted Members" Purchase   30 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 848.0+ bytes

# %%
df.describe()
# Out:
#        Average Delivery Rating (a1)  Average Orders per month (a2)
# count                     30.000000                      30.000000
# mean                       3.066667                      21.000000
# std                        1.040004                      10.763924
# min                        1.500000                      11.000000
# 25%                        2.500000                      13.000000
# 50%                        3.000000                      15.000000
# 75%                        3.500000                      27.000000
# max                        4.500000                      39.000000

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize = (10,5))
ax= sns.violinplot(df['Average Delivery Rating (a1)'])
plt.show()

# %% [markdown]
# No Outliers exists for this field

# %%
plt.figure(figsize = (15,5))
ax= sns.countplot(df['"Delighted Members" Purchase'])
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.01 , p.get_height() * 1.01))
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Balanced Dataset** over "Delighted Members" Purchase' field

# %%
df['"Delighted Members" Purchase'].value_counts(ascending=False)*100/len(df)
# Out:
# Yes    50.0
# No     50.0
# Name: "Delighted Members" Purchase, dtype: float64

# %%
plt.figure(figsize=(10,5))
ax=sns.violinplot(df['Average Orders per month (a2)'])
plt.show()

# %% [markdown]
# No Outliers exists for this field

# %%
plt.figure(figsize = (10,5))
sns.violinplot(y = 'Average Delivery Rating (a1)', x = '"Delighted Members" Purchase', data = df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(y='Average Orders per month (a2)',x='Average Delivery Rating (a1)',hue='"Delighted Members" Purchase',
              split=True,data=df,inner="quartile")
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.violinplot(y = 'Average Orders per month (a2)', x = '"Delighted Members" Purchase', data = df)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.heatmap(df.corr(), annot = True, cmap="rainbow")
plt.show()

# %%
# Putting feature variable to X
X = df.drop('"Delighted Members" Purchase',axis=1)

# Putting response variable to y
y = df['"Delighted Members" Purchase']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=10)
X_train.shape,X_test.shape
# Out:
# ((21, 2), (9, 2))

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Decision Tree over whole dataset

# %%
dt = DecisionTreeClassifier()
dt.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt,
                   feature_names=X.columns,
                   class_names=['Yes', "No"],
                   filled=True)

# %% [markdown]
# Please use the following hyperparameters to solve the following questions:
#
# - max_depth = 5
# - min_samples_split = 10
# - min_samples_leaf = 5
# - Homogeneity measure = Gini

# %%
dt = DecisionTreeClassifier(max_depth = 5,min_samples_split = 10,min_samples_leaf = 5)
dt.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=10)

# %%
from sklearn import tree

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt,
                   feature_names=X.columns,
                   class_names=['Yes', "No"],
                   filled=True)

# %% [markdown]
# ## Decision Tree over test dataset

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
dt = DecisionTreeClassifier(random_state=7)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=7)

# %%
def evaluate_model(dt_classifier):
    print("Train Accuracy :", round(accuracy_score(y_train, dt_classifier.predict(X_train)),2))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_classifier.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", round(accuracy_score(y_test, dt_classifier.predict(X_test)),2))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_classifier.predict(X_test)))

# %%
evaluate_model(dt)
# Out:
# Train Accuracy : 1.0
# Train Confusion Matrix:
# [[11  0]
#  [ 0 10]]
# --------------------------------------------------
# Test Accuracy : 0.89
# Test Confusion Matrix:
# [[4 0]
#  [1 4]]

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt,
                   feature_names=X.columns,
                   class_names=['Yes', "No"],
                   filled=True)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
def evaluate_model(dt_classifier):
    print("Train Accuracy :", round(accuracy_score(y_train, dt_classifier.predict(X_train)),2))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_classifier.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", round(accuracy_score(y_test, dt_classifier.predict(X_test)),2))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_classifier.predict(X_test)))

# %%
evaluate_model(dt)
# Out:
# Train Accuracy : 1.0
# Train Confusion Matrix:
# [[11  0]
#  [ 0 10]]
# --------------------------------------------------
# Test Accuracy : 0.89
# Test Confusion Matrix:
# [[4 0]
#  [1 4]]

# %% [markdown]
# ## Train Accuracy as 1 means overfitting model. Opted for Hyper-parameter tuning of this model

# %%
dt = DecisionTreeClassifier(random_state=50)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [2, 3, 4,5, 6],
    'min_samples_leaf': [1,2,3,4,5],
    'criterion': ["gini", "entropy"]
}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# Wall time: 10.5 s
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=50), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'min_samples_leaf': [1, 2, 3, 4, 5]},
#              scoring='accuracy', verbose=1)

# %%
score_df = pd.DataFrame(grid_search.cv_results_)
score_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.007002      0.001224         0.004249        0.000433
# 1       0.006748      0.000433         0.003251        0.000433
# 2       0.006001      0.000708         0.004750        0.001479
# 3       0.007000      0.001582         0.003500        0.000501
# 4       0.008501      0.002180         0.004750        0.000828
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               2                      1
# 1            gini               2                      2
# 2            gini               2                      3
# 3            gini               2                      4
# 4            gini               2                      5
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           1.000000
# 1  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.666667
# 2  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.666667
# 3  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.666667
# 4  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.666667
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0                1.0                0.8                0.8         0.900000
# 1                0.8                0.8                0.6         0.716667
# 2                0.8                0.8                0.4         0.666667
# 3                0.8                0.8                0.4         0.666667
# 4                0.8                0.8                0.6         0.716667
#
#    std_test_score  rank_test_score
# 0        0.100000                1
# 1        0.086603               11
# 2        0.163299               26
# 3        0.163299               26
# 4        0.086603               11

# %%
score_df.nlargest(5,"mean_test_score")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007002      0.001224         0.004249    4.331879e-04
# 10       0.004500      0.000500         0.003000    9.684608e-07
# 15       0.005499      0.000500         0.003500    8.649992e-04
# 20       0.004998      0.001000         0.003501    4.994870e-04
# 35       0.004499      0.000498         0.003252    4.322658e-04
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 0             gini               2                      1
# 10            gini               4                      1
# 15            gini               5                      1
# 20            gini               6                      1
# 35         entropy               4                      1
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 2, 'min_sam...                1.0
# 10  {'criterion': 'gini', 'max_depth': 4, 'min_sam...                1.0
# 15  {'criterion': 'gini', 'max_depth': 5, 'min_sam...                1.0
# 20  {'criterion': 'gini', 'max_depth': 6, 'min_sam...                1.0
# 35  {'criterion': 'entropy', 'max_depth': 4, 'min_...                1.0
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0                 1.0                0.8                0.8             0.90
# 10                0.8                1.0                0.8             0.90
# 15                0.8                1.0                0.8             0.90
# 20                0.8                1.0                0.8             0.90
# 35                0.6                1.0                0.8             0.85
#
#     std_test_score  rank_test_score
# 0         0.100000                1
# 10        0.100000                1
# 15        0.100000                1
# 20        0.100000                1
# 35        0.165831                5

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=50)

# %%
dt_best = grid_search.best_estimator_

# %%
fig = plt.figure(figsize=(25,10))
_ = tree.plot_tree(dt_best,
                   feature_names=X.columns,
                   class_names=['Yes', "No"],
                   filled=True)

# %%
evaluate_model(dt_best)
# Out:
# Train Accuracy : 0.95
# Train Confusion Matrix:
# [[11  0]
#  [ 1  9]]
# --------------------------------------------------
# Test Accuracy : 0.89
# Test Confusion Matrix:
# [[4 0]
#  [1 4]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, dt_best.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.80      1.00      0.89         4
#          Yes       1.00      0.80      0.89         5
#
#     accuracy                           0.89         9
#    macro avg       0.90      0.90      0.89         9
# weighted avg       0.91      0.89      0.89         9

# %%
print(classification_report(y_train, dt_best.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.92      1.00      0.96        11
#          Yes       1.00      0.90      0.95        10
#
#     accuracy                           0.95        21
#    macro avg       0.96      0.95      0.95        21
# weighted avg       0.96      0.95      0.95        21
